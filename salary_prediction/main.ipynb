# %%
#https://www.kaggle.com/johnolafenwa/us-census-data#adult-training.csv
import tensorflow as tf
import tensorflow.contrib as contrib
import pandas as pd
import tempfile
import numpy as np

# %%
#READ FILES
df_train = pd.read_csv("adult-training.csv")
df_test = pd.read_csv("adult-test.csv")

# %%
data_types = df_train.dtypes

# %%
data_types
# Out:
# 39                 int64
#  State-gov        object
#  77516             int64
#  Bachelors        object
#  13                int64
#  Never-married    object
#  Adm-clerical     object
#  Not-in-family    object
#  White            object
#  Male             object
#  2174              int64
#  0                 int64
#  40                int64
#  United-States    object
#  <=50K            object
# dtype: object

# %%
column_names = ["age", "workclass", "fnlwgt", "education", "education_num",
           "marital_status", "occupation", "relationship", "race", 
           "gender", "capital_gain", "capital_loss", "hours_per_week", 
           "native_country","income_bracket"]

df_train.columns = column_names

# %%
df_train.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income_bracket'],
#       dtype='object')

# %%
data_types = df_train.dtypes

# %%
data_types
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# gender            object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income_bracket    object
# dtype: object

# %%
#get numeric columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_columns = df_train.select_dtypes(include=numerics).columns
categorical_columns=df_train.select_dtypes(exclude=numerics).columns

# %%
categorical_columns
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'income_bracket'],
#       dtype='object')

# %%
df_test.select_dtypes(include='int')
# Out:
# Empty DataFrame
# Columns: []
# ...
